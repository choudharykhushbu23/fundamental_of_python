# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\khushbu\Desktop\project.csv")
print(df)
# Out:
#      Name  Study hours  Screentime  Sleep hours  Attendance  Marks
# 0   Aditi            6           2            6          90     89
# 1   Rahul            3           6            4          75     58
# 2    Neha            8           1            6         100     95
# 3    Aman            5           3            7          78     70
# 4   Priya            7           2            6          90     91
# 5   Mohit            3           7            5          56     50
# 6  Simran            6           2            4          89     80
# 7   Karan            6           1            3          90     91
# 8   Arjun            7           1            2          89     86
# 9   Kajal            8           2            8          90     93
