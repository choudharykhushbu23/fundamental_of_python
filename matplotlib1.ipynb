# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [2,4,6,8]
plt.plot(x,y)
plt.title("Graph of x and y")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [2,4,6,8]
plt.scatter(x,y)
plt.title("Graph of x and y")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [2,4,6,8]
plt.hist(x,y,color="pink",width=1)
plt.title("Graph of x and y")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
marks = [40,30,20,10]
subjects = ["Math","Science","English","Computer"]
plt.pie(marks,labels=subjects,autopct="%1.1f%%")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
marks = [40,30,20,10]
subjects = ["Math","Science","English","Computer"]
plt.pie(marks,labels=subjects,autopct="%1.1f%%",explode=[0,0,3,0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [2,4,6,8]
plt.bar(x,y,color="pink")
plt.title("Graph of x and y")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [2,4,6,8]
plt.barh(x,y,color="pink")
plt.title("Graph of x and y")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y1 = [2,4,6,8]
y2 = [1,3,5,7]
plt.plot(x,y1,label="Product A")
plt.plot(x,y2,label="Product B")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x = [5,13,15,20]
y = [10,20,30,40]
plt.xlabel("data of school")
plt.ylabel("data of student present")
plt.plot(x,y,linestyle=":",linewidth=2,marker="o",label="accedmic data")
plt.legend()
plt.grid()
plt.title("school attendence data")
plt.show()

# %%
import matplotlib.pyplot as plt
data = [2,10,20,30,50,30,50,20,10,10,10]
plt.hist(data,color='purple',edgecolor='black')
plt.xlabel("data of goods")
plt.ylabel("data of purchase")
plt.title("product data")
plt.show()

# %%
x=[5,13,15,20]
y=[10,20,30,40]
plt.scatter(x,y,color='red',marker='x')
plt.xlabel("data X")
plt.ylabel("data Y")
plt.title("model data")
plt.show()

# %%
# ploting scatter plot with marking the points
x=[5,13,15,20]
y=[10,20,30,40]
labels=['A','B','C','D']
plt.scatter(x,y)
for i in range(len(x)):
    plt.text(x[i],y[i],labels[i],fontsize=12, color='red')
plt.show()

# %%
x=[5,13,15,20]
y=[10,20,30,40]
plt.scatter(x,y)
for i in range(len(x)):
    plt.text(x[i]+0.1,y[i]+0.5,f"({x[i]},{y[i]})",fontsize=10,color='red')
plt.grid()    
    
plt.show()

# %%
# if we need to display multple graph data at one data graph using scatterplot
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,20,30,40],color="orange",label='team A')
plt.scatter([11,14,12,15],[20,40,60,80],color='red',label='team B')
plt.legend()
plt.show()

# %%
#subplot
import matplotlib.pyplot as plt
x=[5,13,15,20]
y=[10,20,30,40]
#graph 1
plt.subplot(1,2,1)#(row,column,part)
plt.plot(x,y)
# graph 2
plt.subplot(1,2,2)#(row,column,part)
plt.bar(x,y)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create DataFrame
data = {
    'Product_ID': [101,102,103,104,105,106,107,108,109,110],
    'Product_Name': ['Laptop','Mouse','Keyboard','Monitor','Headphones',
                     'Printer','Tablet','Camera','Smartphone','Speaker'],
    'Category': ['Electronics','Accessories','Accessories','Electronics',
                 'Accessories','Electronics','Electronics','Electronics',
                 'Electronics','Electronics'],
    'Price': [70000,1200,2500,15000,2000,10000,25000,30000,40000,3500],
    'Quantity': [5,50,40,10,35,7,15,8,12,25],
    'Discount(%)': [10,5,5,8,10,15,7,10,12,5]
}

df = pd.DataFrame(data)

# Calculate Sales (Price × Quantity)
df['Sales'] = df['Price'] * df['Quantity']

print(df)

# Plot Sales and Discount in one frame
plt.figure(figsize=(10,5))

plt.plot(df['Product_Name'], df['Sales'],
         marker='o', label='Sales')

plt.plot(df['Product_Name'], df['Discount(%)'],
         marker='s', label='Discount (%)')

plt.title("Sales and Discount Comparison")
plt.xlabel("Product Name")
plt.ylabel("Values")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

plt.show()
# Out:
#    Product_ID Product_Name     Category  Price  Quantity  Discount(%)   Sales
# 0         101       Laptop  Electronics  70000         5           10  350000
# 1         102        Mouse  Accessories   1200        50            5   60000
# 2         103     Keyboard  Accessories   2500        40            5  100000
# 3         104      Monitor  Electronics  15000        10            8  150000
# 4         105   Headphones  Accessories   2000        35           10   70000
# 5         106      Printer  Electronics  10000         7           15   70000
# 6         107       Tablet  Electronics  25000        15            7  375000
# 7         108       Camera  Electronics  30000         8           10  240000
# 8         109   Smartphone  Electronics  40000        12           12  480000
# 9         110      Speaker  Electronics   3500        25            5   87500
